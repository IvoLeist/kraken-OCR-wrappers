# %%
from google.colab import drive
from pathlib import Path
import os

drive.mount("/content/drive")

REMOTE_COLAB_BRIDGE = Path("/content/drive/MyDrive/colab_bridge/kraken-ocr")
REMOTE_COLAB_BRIDGE.mkdir(parents=True, exist_ok=True)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
EXAMPLE_INPUT_DIR = REMOTE_COLAB_BRIDGE / "example_input"
EXAMPLE_INPUT_DIR.mkdir(parents=True, exist_ok=True)
os.environ["EXAMPLE_INPUT_DIR"] = str(EXAMPLE_INPUT_DIR)

OUTPUT_DIR = REMOTE_COLAB_BRIDGE / "output"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
os.environ["OUTPUT_DIR"] = str(OUTPUT_DIR)

# %%
# !pip install uv
# !uv pip install kraken
# Out:
# ...
# Using Python 3.12.13 environment at: /usr
# Checked 1 package in 79ms

# %%
# !wget -P "$EXAMPLE_INPUT_DIR" https://raw.githubusercontent.com/mittagessen/kraken/refs/heads/main/tests/resources/input_bw.png
# Out:
# --2026-06-22 10:32:57--  https://raw.githubusercontent.com/mittagessen/kraken/refs/heads/main/tests/resources/input_bw.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 58995 (58K) [image/png]
# Saving to: ‘/content/drive/MyDrive/colab_bridge/kraken-ocr/example_input/input_bw.png’
#
# input_bw.png        100%[===================>]  57.61K  --.-KB/s    in 0.004s
#
# 2026-06-22 10:32:57 (13.5 MB/s) - ‘/content/drive/MyDrive/colab_bridge/kraken-ocr/example_input/input_bw.png’ saved [58995/58995]

# %%
# !ls -l input_bw.png
# !pwd
# Out:
# -rw-r--r-- 1 root root 58995 Jun 22 09:26 input_bw.png
# /content
